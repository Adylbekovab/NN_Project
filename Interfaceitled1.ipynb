# %% [markdown]
# <a href="https://colab.research.google.com/github/Adylbekovab/NN_Project/blob/main/Interfaceitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Интерфейс генерации описания изображения без использования Gradio (обход ограничений среды)
from PIL import Image
import io

# Заглушка для генерации подписи — замените на вызов вашей модели
def generate_caption(image):
    # Здесь должен быть код, извлекающий признаки из изображения и генерирующий текст
    return "Описание будет здесь"

if __name__ == "__main__":
    print("Ожидается байтовый ввод изображения. Пожалуйста, используйте этот скрипт в интегрированной среде или с API.")

    try:
        # Пример: открыть изображение из файла, если окружение позволяет
        # Если среда не поддерживает input, лучше работать с изображением, уже загруженным в байтах
        with open("example.jpg", "rb") as f:
            image_data = f.read()
        image = Image.open(io.BytesIO(image_data))
        caption = generate_caption(image)
        print(f"Сгенерированное описание: {caption}")
    except FileNotFoundError:
        print("Файл 'example.jpg' не найден. Загрузите изображение в директорию скрипта или измените путь.")
    except Exception as e:
        print(f"Ошибка при обработке изображения: {e}")
# Out:
# Ожидается байтовый ввод изображения. Пожалуйста, используйте этот скрипт в интегрированной среде или с API.
# Файл 'example.jpg' не найден. Загрузите изображение в директорию скрипта или измените путь.
